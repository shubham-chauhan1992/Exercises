# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("WaterQualityingestionjob").getOrCreate()

# %%
json_df=spark.read.json('/mnt/adls/landingzone/waterqualityextract/*.json')
display(json_df)

# %%
json_df.write.format("delta").mode("overwrite").save('/mnt/adls/bronze/water_quality')

# %%
display(dbutils.fs.ls('/mnt/adls/bronze/water_quality'))
